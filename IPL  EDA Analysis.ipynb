# %%
# import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\ASUS\Desktop\Projects\IPL\IPL Ball-by-Ball 2008-2020.csv',index_col=0,header=0)
df.head()
# Out:
#         inning  over  ball      batsman  non_striker     bowler  batsman_runs  \
# id
# 335982       1     6     5   RT Ponting  BB McCullum  AA Noffke             1
# 335982       1     6     6  BB McCullum   RT Ponting  AA Noffke             1
# 335982       1     7     1  BB McCullum   RT Ponting     Z Khan             0
# 335982       1     7     2  BB McCullum   RT Ponting     Z Khan             1
# 335982       1     7     3   RT Ponting  BB McCullum     Z Khan             1
#
#         extra_runs  total_runs  non_boundary  is_wicket dismissal_kind  \
# id
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           0             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
#
#        player_dismissed fielder extras_type           batting_team  \
# id
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
#
#                        bowling_team
# id
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore

# %% [markdown]
# # Checking IPL Dataset Attributes

# %% [markdown]
# Before we proceed with our Python data analysis of IPL data, we should know what columns are present in the dataset, their count, and data type. For this, we use Pandas info() function.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193468 entries, 335982 to 1237181
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   inning            193468 non-null  int64
#  1   over              193468 non-null  int64
#  2   ball              193468 non-null  int64
#  3   batsman           193468 non-null  object
#  4   non_striker       193468 non-null  object
#  5   bowler            193468 non-null  object
#  6   batsman_runs      193468 non-null  int64
#  7   extra_runs        193468 non-null  int64
#  8   total_runs        193468 non-null  int64
#  9   non_boundary      193468 non-null  int64
#  10  is_wicket         193468 non-null  int64
#  11  dismissal_kind    9495 non-null    object
#  12  player_dismissed  9495 non-null    object
#  13  fielder           6784 non-null    object
#  14  extras_type       10233 non-null   object
#  15  batting_team      193468 non-null  object
#  16  bowling_team      193277 non-null  object
# dtypes: int64(8), object(9)
# memory usage: 26.6+ MB

# %% [markdown]
# # i) General Analysis of IPL Matches

# %% [markdown]
# # 1. List of Seasons

# %% [markdown]
# The data set we have includes the data of each and every match played from season 2008 to 2021.

# %%
df.describe()
# Out:
#               inning           over           ball   batsman_runs  \
# count  193468.000000  193468.000000  193468.000000  193468.000000
# mean        1.482131       9.177027       3.615967       1.240231
# std         0.499682       5.676848       1.807128       1.610867
# min         1.000000       0.000000       1.000000       0.000000
# 25%         1.000000       4.000000       2.000000       0.000000
# 50%         1.000000       9.000000       4.000000       1.000000
# 75%         2.000000      14.000000       5.000000       1.000000
# max         2.000000      19.000000       9.000000       6.000000
#
#           extra_runs     total_runs   non_boundary      is_wicket
# count  193468.000000  193468.000000  193468.000000  193468.000000
# mean        0.066414       1.306645       0.000083       0.049078
# std         0.339991       1.598802       0.009094       0.216031
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       1.000000       0.000000       0.000000
# 75%         0.000000       1.000000       0.000000       0.000000
# max         7.000000       7.000000       1.000000       1.000000

# %%
df.shape
# Out:
# (193468, 17)

# %%
print(f"This Dataset have {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# This Dataset have 193468 rows and 17 columns.

# %%
# Checking Null Values
num_null = df.isnull().sum().sum()
print("No of Null Values: {}".format(num_null))
# Out:
# No of Null Values: 738056

# %%
plt.figure(figsize=(18, 18))

sns.displot(
data = df.isna().melt(value_name="Null Values"),
y = "variable",
hue = "Null Values",
multiple="fill",
aspect=3,
palette='PuBuGn_r' 
)
plt.title('Non-Missing Values in Ball by Ball data', weight = 'bold', size = 20, color = 'brown')
plt.xlabel(" ")
plt.ylabel(" ")
plt.xticks(size = 12, weight = 'bold', color = 'maroon')
plt.yticks(size = 12, weight = 'bold', color = 'maroon');

# %%
corelation = df.corr()

# %%
plt.figure(figsize=(18, 18))
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#         inning  over  ball      batsman  non_striker     bowler  batsman_runs  \
# id
# 335982       1     6     5   RT Ponting  BB McCullum  AA Noffke             1
# 335982       1     6     6  BB McCullum   RT Ponting  AA Noffke             1
# 335982       1     7     1  BB McCullum   RT Ponting     Z Khan             0
# 335982       1     7     2  BB McCullum   RT Ponting     Z Khan             1
# 335982       1     7     3   RT Ponting  BB McCullum     Z Khan             1
#
#         extra_runs  total_runs  non_boundary  is_wicket dismissal_kind  \
# id
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           0             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
#
#        player_dismissed fielder extras_type           batting_team  \
# id
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
#
#                        bowling_team
# id
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore

# %% [markdown]
# # Most Runs Scored

# %%
most_runs = df.groupby(['id'])['total_runs'].sum().reset_index()

# %%
most_runs.head()
# Out:
#        id  total_runs
# 0  335982         304
# 1  335983         447
# 2  335984         261
# 3  335985         331
# 4  335986         222

# %%
# Ascending Order
asc_most_runs = most_runs.sort_values(by="total_runs", ascending=True)
asc_most_runs
# Out:
#           id  total_runs
# 241   501265          56
# 744  1178424         103
# 39    336021         135
# 611  1082626         135
# 411   729305         141
# ..       ...         ...
# 1     335983         447
# 791  1216527         449
# 626  1082641         453
# 679  1136604         459
# 146   419137         469
#
# [816 rows x 2 columns]

# %%
# Descending Order
desc_most_runs = most_runs.sort_values(by="total_runs", ascending=False)
desc_most_runs
# Out:
#           id  total_runs
# 146   419137         469
# 679  1136604         459
# 626  1082641         453
# 791  1216527         449
# 1     335983         447
# ..       ...         ...
# 411   729305         141
# 611  1082626         135
# 39    336021         135
# 744  1178424         103
# 241   501265          56
#
# [816 rows x 2 columns]

# %%
sns.pairplot(asc_most_runs)

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(r'C:\Users\ASUS\Desktop\Projects\IPL\IPL Matches 2008-2020.csv',index_col=0,header=0)

# %%
matches.head()
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs          140.0          N    NaN
# 335983          Chennai Super Kings     runs           33.0          N    NaN
# 335984             Delhi Daredevils  wickets            9.0          N    NaN
# 335985  Royal Challengers Bangalore  wickets            5.0          N    NaN
# 335986        Kolkata Knight Riders  wickets            5.0          N    NaN
#
#           umpire1         umpire2
# id
# 335982  Asad Rauf     RE Koertzen
# 335983  MR Benson      SL Shastri
# 335984  Aleem Dar  GA Pratapkumar
# 335985   SJ Davis       DJ Harper
# 335986  BF Bowden     K Hariharan

# %%
matches.tail()
# Out:
#               city        date player_of_match  \
# id
# 1216547      Dubai  2020-09-28  AB de Villiers
# 1237177      Dubai  2020-11-05       JJ Bumrah
# 1237178  Abu Dhabi  2020-11-06   KS Williamson
# 1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 1237181      Dubai  2020-11-10        TA Boult
#
#                                        venue  neutral_venue  \
# id
# 1216547  Dubai International Cricket Stadium              0
# 1237177  Dubai International Cricket Stadium              0
# 1237178                 Sheikh Zayed Stadium              0
# 1237180                 Sheikh Zayed Stadium              0
# 1237181  Dubai International Cricket Stadium              0
#
#                                team1                team2  \
# id
# 1216547  Royal Challengers Bangalore       Mumbai Indians
# 1237177               Mumbai Indians       Delhi Capitals
# 1237178  Royal Challengers Bangalore  Sunrisers Hyderabad
# 1237180               Delhi Capitals  Sunrisers Hyderabad
# 1237181               Delhi Capitals       Mumbai Indians
#
#                  toss_winner toss_decision                       winner  \
# id
# 1216547       Mumbai Indians         field  Royal Challengers Bangalore
# 1237177       Delhi Capitals         field               Mumbai Indians
# 1237178  Sunrisers Hyderabad         field          Sunrisers Hyderabad
# 1237180       Delhi Capitals           bat               Delhi Capitals
# 1237181       Delhi Capitals           bat               Mumbai Indians
#
#           result  result_margin eliminator method      umpire1      umpire2
# id
# 1216547      tie            NaN          Y    NaN  Nitin Menon   PR Reiffel
# 1237177     runs           57.0          N    NaN  CB Gaffaney  Nitin Menon
# 1237178  wickets            6.0          N    NaN   PR Reiffel       S Ravi
# 1237180     runs           17.0          N    NaN   PR Reiffel       S Ravi
# 1237181  wickets            5.0          N    NaN  CB Gaffaney  Nitin Menon

# %%
# Adding Season Year in DF
matches['season'] = pd.DatetimeIndex(matches['date']).year

# %%
matches.head()
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs          140.0          N    NaN
# 335983          Chennai Super Kings     runs           33.0          N    NaN
# 335984             Delhi Daredevils  wickets            9.0          N    NaN
# 335985  Royal Challengers Bangalore  wickets            5.0          N    NaN
# 335986        Kolkata Knight Riders  wickets            5.0          N    NaN
#
#           umpire1         umpire2
# id
# 335982  Asad Rauf     RE Koertzen
# 335983  MR Benson      SL Shastri
# 335984  Aleem Dar  GA Pratapkumar
# 335985   SJ Davis       DJ Harper
# 335986  BF Bowden     K Hariharan

# %%
matches.isnull().sum()
# Out:
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
num_matches_null = matches.isnull().sum().sum()
print("Matches have {} null values.".format(num_matches_null))
# Out:
# Matches have 843 null values.

# %%
# as we see method column has most null values
cd = matches.dropna(subset=['method'])

# %%
cd.head()
# Out:
#              city        date   player_of_match             venue  \
# id
# 336022      Delhi  2008-05-17  DPMD Jayawardene  Feroz Shah Kotla
# 336025    Kolkata  2008-05-18           M Ntini      Eden Gardens
# 392183  Cape Town  2009-04-19        DL Vettori          Newlands
# 392186     Durban  2009-04-21          CH Gayle         Kingsmead
# 392214  Centurion  2009-05-07         ML Hayden   SuperSport Park
#
#         neutral_venue                  team1                  team2  \
# id
# 336022              0       Delhi Daredevils        Kings XI Punjab
# 336025              0  Kolkata Knight Riders    Chennai Super Kings
# 392183              1       Delhi Daredevils        Kings XI Punjab
# 392186              1        Kings XI Punjab  Kolkata Knight Riders
# 392214              1    Chennai Super Kings        Kings XI Punjab
#
#                   toss_winner toss_decision                 winner   result  \
# id
# 336022       Delhi Daredevils           bat        Kings XI Punjab     runs
# 336025  Kolkata Knight Riders           bat    Chennai Super Kings     runs
# 392183       Delhi Daredevils         field       Delhi Daredevils  wickets
# 392186  Kolkata Knight Riders         field  Kolkata Knight Riders     runs
# 392214    Chennai Super Kings           bat    Chennai Super Kings     runs
#
#         result_margin eliminator method         umpire1         umpire2  \
# id
# 336022            6.0          N    D/L  AV Jayaprakash     RE Koertzen
# 336025            3.0          N    D/L       Asad Rauf     K Hariharan
# 392183           10.0          N    D/L       MR Benson       SD Ranade
# 392186           11.0          N    D/L       DJ Harper       SD Ranade
# 392214           12.0          N    D/L       DJ Harper  TH Wijewardene
#
#         season
# id
# 336022    2008
# 336025    2008
# 392183    2009
# 392186    2009
# 392214    2009

# %%
cd.describe()
# Out:
#        neutral_venue  result_margin       season
# count      19.000000      19.000000    19.000000
# mean        0.157895      14.000000  2013.421053
# std         0.374634      17.885438     3.671448
# min         0.000000       3.000000  2008.000000
# 25%         0.000000       6.500000  2010.000000
# 50%         0.000000       9.000000  2015.000000
# 75%         0.000000      11.500000  2016.000000
# max         1.000000      82.000000  2018.000000

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 336022 to 1136592
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             19 non-null     object
#  1   date             19 non-null     object
#  2   player_of_match  19 non-null     object
#  3   venue            19 non-null     object
#  4   neutral_venue    19 non-null     int64
#  5   team1            19 non-null     object
#  6   team2            19 non-null     object
#  7   toss_winner      19 non-null     object
#  8   toss_decision    19 non-null     object
#  9   winner           19 non-null     object
#  10  result           19 non-null     object
#  11  result_margin    19 non-null     float64
#  12  eliminator       19 non-null     object
#  13  method           19 non-null     object
#  14  umpire1          19 non-null     object
#  15  umpire2          19 non-null     object
#  16  season           19 non-null     int64
# dtypes: float64(1), int64(2), object(14)
# memory usage: 2.7+ KB

# %%
m_corr = cd.corr()
plt.figure(figsize=(18, 18))
sns.heatmap(m_corr, xticklabels=m_corr.columns, yticklabels=m_corr.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
m_corr = cd.corr()
sns.heatmap(m_corr, xticklabels=m_corr.columns, yticklabels=m_corr.columns)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(17, 17))
sns.displot(
data=matches.isna().melt(value_name="Null Values"),
y="variable",
hue="Null Values",
palette="PuBuGn_r",
multiple="fill",
aspect=3
)
plt.title('Non-Missing Values in Matches data', weight = 'bold', size = 20, color = 'brown')
plt.xlabel(" ")
plt.ylabel(" ")
plt.xticks(size = 12, weight = 'bold', color = 'maroon')
plt.yticks(size = 12, weight = 'bold', color = 'maroon');

# %%
merged = desc_most_runs[['id', 'total_runs']].merge(matches, left_on='id', right_on='id', how='left')

# %%
merged.head()
# Out:
#         id  total_runs        city        date player_of_match  \
# 0   419137         469     Chennai  2010-04-03         M Vijay
# 1  1136604         459      Indore  2018-05-12       SP Narine
# 2  1082641         453      Mumbai  2017-05-11         WP Saha
# 3  1216527         449     Sharjah  2020-09-27       SV Samson
# 4   335983         447  Chandigarh  2008-04-19      MEK Hussey
#
#                                         venue  neutral_venue  \
# 0             MA Chidambaram Stadium, Chepauk              0
# 1                      Holkar Cricket Stadium              0
# 2                            Wankhede Stadium              0
# 3                     Sharjah Cricket Stadium              0
# 4  Punjab Cricket Association Stadium, Mohali              0
#
#                  team1                  team2          toss_winner  \
# 0  Chennai Super Kings       Rajasthan Royals  Chennai Super Kings
# 1      Kings XI Punjab  Kolkata Knight Riders      Kings XI Punjab
# 2       Mumbai Indians        Kings XI Punjab       Mumbai Indians
# 3      Kings XI Punjab       Rajasthan Royals     Rajasthan Royals
# 4      Kings XI Punjab    Chennai Super Kings  Chennai Super Kings
#
#   toss_decision                 winner   result  result_margin eliminator  \
# 0           bat    Chennai Super Kings     runs           23.0          N
# 1         field  Kolkata Knight Riders     runs           31.0          N
# 2         field        Kings XI Punjab     runs            7.0          N
# 3         field       Rajasthan Royals  wickets            4.0          N
# 4           bat    Chennai Super Kings     runs           33.0          N
#
#   method         umpire1         umpire2  season
# 0    NaN     RE Koertzen       RB Tiffin    2010
# 1    NaN       VK Sharma       CK Nandan    2018
# 2    NaN      A Deshmukh  A Nand Kishore    2017
# 3    NaN  RK Illingworth    K Srinivasan    2020
# 4    NaN       MR Benson      SL Shastri    2008

# %%
# total runs in each season
season_most_runs = merged.groupby(['season'])['total_runs'].sum().reset_index()
season_most_runs
# Out:
#     season  total_runs
# 0     2008       17937
# 1     2009       16320
# 2     2010       18864
# 3     2011       21154
# 4     2012       22453
# 5     2013       22541
# 6     2014       18909
# 7     2015       18332
# 8     2016       18862
# 9     2017       18769
# 10    2018       19901
# 11    2019       19400
# 12    2020       19352

# %%
print("Most runs {} is in the season {}.".format(season_most_runs.max()['total_runs'], season_most_runs.max()['season']))
# Out:
# Most runs 22541 is in the season 2020.

# %%
#Ascending
season_most_runs.sort_values(by='total_runs', ascending=True)
# Out:
#     season  total_runs
# 1     2009       16320
# 0     2008       17937
# 7     2015       18332
# 9     2017       18769
# 8     2016       18862
# 2     2010       18864
# 6     2014       18909
# 12    2020       19352
# 11    2019       19400
# 10    2018       19901
# 3     2011       21154
# 4     2012       22453
# 5     2013       22541

# %%
# Descending
season_most_runs.sort_values(by='total_runs', ascending=False)
# Out:
#     season  total_runs
# 5     2013       22541
# 4     2012       22453
# 3     2011       21154
# 10    2018       19901
# 11    2019       19400
# 12    2020       19352
# 6     2014       18909
# 2     2010       18864
# 8     2016       18862
# 9     2017       18769
# 7     2015       18332
# 0     2008       17937
# 1     2009       16320

# %%
sns.pairplot(season_most_runs)

# %%
sns.relplot(x='season', y='total_runs', data=season_most_runs, hue='season')

# %%
merged.head()
# Out:
#         id  total_runs        city        date player_of_match  \
# 0   419137         469     Chennai  2010-04-03         M Vijay
# 1  1136604         459      Indore  2018-05-12       SP Narine
# 2  1082641         453      Mumbai  2017-05-11         WP Saha
# 3  1216527         449     Sharjah  2020-09-27       SV Samson
# 4   335983         447  Chandigarh  2008-04-19      MEK Hussey
#
#                                         venue  neutral_venue  \
# 0             MA Chidambaram Stadium, Chepauk              0
# 1                      Holkar Cricket Stadium              0
# 2                            Wankhede Stadium              0
# 3                     Sharjah Cricket Stadium              0
# 4  Punjab Cricket Association Stadium, Mohali              0
#
#                  team1                  team2          toss_winner  \
# 0  Chennai Super Kings       Rajasthan Royals  Chennai Super Kings
# 1      Kings XI Punjab  Kolkata Knight Riders      Kings XI Punjab
# 2       Mumbai Indians        Kings XI Punjab       Mumbai Indians
# 3      Kings XI Punjab       Rajasthan Royals     Rajasthan Royals
# 4      Kings XI Punjab    Chennai Super Kings  Chennai Super Kings
#
#   toss_decision                 winner   result  result_margin eliminator  \
# 0           bat    Chennai Super Kings     runs           23.0          N
# 1         field  Kolkata Knight Riders     runs           31.0          N
# 2         field        Kings XI Punjab     runs            7.0          N
# 3         field       Rajasthan Royals  wickets            4.0          N
# 4           bat    Chennai Super Kings     runs           33.0          N
#
#   method         umpire1         umpire2  season
# 0    NaN     RE Koertzen       RB Tiffin    2010
# 1    NaN       VK Sharma       CK Nandan    2018
# 2    NaN      A Deshmukh  A Nand Kishore    2017
# 3    NaN  RK Illingworth    K Srinivasan    2020
# 4    NaN       MR Benson      SL Shastri    2008

# %%
df.head()
# Out:
#         inning  over  ball      batsman  non_striker     bowler  batsman_runs  \
# id
# 335982       1     6     5   RT Ponting  BB McCullum  AA Noffke             1
# 335982       1     6     6  BB McCullum   RT Ponting  AA Noffke             1
# 335982       1     7     1  BB McCullum   RT Ponting     Z Khan             0
# 335982       1     7     2  BB McCullum   RT Ponting     Z Khan             1
# 335982       1     7     3   RT Ponting  BB McCullum     Z Khan             1
#
#         extra_runs  total_runs  non_boundary  is_wicket dismissal_kind  \
# id
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           0             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
#
#        player_dismissed fielder extras_type           batting_team  \
# id
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
#
#                        bowling_team
# id
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore

# %%
# most runs scored by which batsman
most_runs_by_batsman = df.groupby('batsman')['total_runs'].sum().reset_index()
most_runs_by_batsman
# Out:
#             batsman  total_runs
# 0    A Ashish Reddy         288
# 1        A Chandila           4
# 2          A Chopra          58
# 3       A Choudhary          25
# 4       A Dananjaya           4
# ..              ...         ...
# 532     YV Takawale         207
# 533   Yashpal Singh          49
# 534     Younis Khan           3
# 535    Yuvraj Singh        2880
# 536          Z Khan         121
#
# [537 rows x 2 columns]

# %%
sort_most_runs_by_batsman = most_runs_by_batsman.sort_values(by='total_runs', ascending=False)
sort_most_runs_by_batsman
# Out:
#             batsman  total_runs
# 505         V Kohli        6081
# 438        SK Raina        5604
# 116       DA Warner        5522
# 407        S Dhawan        5452
# 379       RG Sharma        5394
# ..              ...         ...
# 387      RR Bhatkal           0
# 91          C Nanda           0
# 413    S Lamichhane           0
# 506  V Pratap Singh           0
# 228        KK Ahmed           0
#
# [537 rows x 2 columns]

# %%
max_runs = sort_most_runs_by_batsman.max()['total_runs']
max_player = sort_most_runs_by_batsman.max()['batsman']

# %%
print(f"Most runs of {max_runs} is by {max_player}.")
# Out:
# Most runs of 6081 is by Z Khan.

# %%
sort_most_runs_by_batsman[sort_most_runs_by_batsman['total_runs'] != 0]
# Out:
#            batsman  total_runs
# 505        V Kohli        6081
# 438       SK Raina        5604
# 116      DA Warner        5522
# 407       S Dhawan        5452
# 379      RG Sharma        5394
# ..             ...         ...
# 166      HF Gurney           1
# 251    LE Plunkett           1
# 81    BE Hendricks           1
# 469  Shahbaz Ahmed           1
# 474   Shoaib Ahmed           1
#
# [520 rows x 2 columns]

# %%
# top 10
sort_most_runs_by_batsman[:10]
# Out:
#             batsman  total_runs
# 505         V Kohli        6081
# 438        SK Raina        5604
# 116       DA Warner        5522
# 407        S Dhawan        5452
# 379       RG Sharma        5394
# 96         CH Gayle        5103
# 24   AB de Villiers        5016
# 398      RV Uthappa        4878
# 301        MS Dhoni        4855
# 154       G Gambhir        4479

# %%
sort_most_runs_by_batsman.set_index('batsman', inplace=True)

# %%
top_batsman_20 = sort_most_runs_by_batsman[:20]

# %%
top_batsman_20.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='batsman'>

# %%
# We have seen that most runs scored by virat kholi.
matches.head()
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs          140.0          N    NaN
# 335983          Chennai Super Kings     runs           33.0          N    NaN
# 335984             Delhi Daredevils  wickets            9.0          N    NaN
# 335985  Royal Challengers Bangalore  wickets            5.0          N    NaN
# 335986        Kolkata Knight Riders  wickets            5.0          N    NaN
#
#           umpire1         umpire2  season
# id
# 335982  Asad Rauf     RE Koertzen    2008
# 335983  MR Benson      SL Shastri    2008
# 335984  Aleem Dar  GA Pratapkumar    2008
# 335985   SJ Davis       DJ Harper    2008
# 335986  BF Bowden     K Hariharan    2008

# %%
matches.toss_winner
# Out:
# id
# 335982     Royal Challengers Bangalore
# 335983             Chennai Super Kings
# 335984                Rajasthan Royals
# 335985                  Mumbai Indians
# 335986                 Deccan Chargers
#                       ...
# 1216547                 Mumbai Indians
# 1237177                 Delhi Capitals
# 1237178            Sunrisers Hyderabad
# 1237180                 Delhi Capitals
# 1237181                 Delhi Capitals
# Name: toss_winner, Length: 816, dtype: object

# %%
matches.winner
# Out:
# id
# 335982           Kolkata Knight Riders
# 335983             Chennai Super Kings
# 335984                Delhi Daredevils
# 335985     Royal Challengers Bangalore
# 335986           Kolkata Knight Riders
#                       ...
# 1216547    Royal Challengers Bangalore
# 1237177                 Mumbai Indians
# 1237178            Sunrisers Hyderabad
# 1237180                 Delhi Capitals
# 1237181                 Mumbai Indians
# Name: winner, Length: 816, dtype: object

# %%
winner_toss = matches.toss_winner == matches.winner

# %%
winner_toss.value_counts()
# Out:
# True     418
# False    398
# dtype: int64

# %%
winner_toss.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
import warnings

# %%
winner_losers = {
    "Matches wins (Toss Wins)": 418,
    "Matches Loss (Toss Loss)": 398
}
warnings.filterwarnings("ignore")
winners_losers = pd.Series(winner_losers)
plt.figure(figsize=(9, 9))
plt.pie(x=winners_losers, labels=winners_losers.index, autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x20426825cd0>,
#   <matplotlib.patches.Wedge at 0x20426832490>],
#  [Text(-0.042339411351007016, 1.0991848680938299, 'Matches wins (Toss Wins)'),
#   Text(0.04233941135100639, -1.09918486809383, 'Matches Loss (Toss Loss)')],
#  [Text(-0.023094224373276552, 0.5995553825966344, '51.23%'),
#   Text(0.02309422437327621, -0.5995553825966345, '48.77%')])

# %%
# so from pie chart er can see that is a team wins the toss most of the times it wins the match
plt.figure(figsize=(7, 10))
sns.countplot(y="winner", data=matches, palette="copper")
plt.title("Most Matches won by Teams", fontsize=12)
plt.xlabel("No of Matches")
plt.ylabel("Teams")
# Out:
# Text(0, 0.5, 'Teams')

# %%
# as you can see that most matches won by KKR.

# %%
matches.head()
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs          140.0          N    NaN
# 335983          Chennai Super Kings     runs           33.0          N    NaN
# 335984             Delhi Daredevils  wickets            9.0          N    NaN
# 335985  Royal Challengers Bangalore  wickets            5.0          N    NaN
# 335986        Kolkata Knight Riders  wickets            5.0          N    NaN
#
#           umpire1         umpire2  season
# id
# 335982  Asad Rauf     RE Koertzen    2008
# 335983  MR Benson      SL Shastri    2008
# 335984  Aleem Dar  GA Pratapkumar    2008
# 335985   SJ Davis       DJ Harper    2008
# 335986  BF Bowden     K Hariharan    2008

# %%
plt.figure(figsize=(7, 10))
sns.countplot(y="season", data=matches, palette="YlGnBu")
plt.title("Most matches played in season", fontsize=12)
plt.xlabel("Matches")
plt.ylabel("Season")
# Out:
# Text(0, 0.5, 'Season')

# %%
# as you can see that more matches played in season 2013

# %%
matches.head()
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs          140.0          N    NaN
# 335983          Chennai Super Kings     runs           33.0          N    NaN
# 335984             Delhi Daredevils  wickets            9.0          N    NaN
# 335985  Royal Challengers Bangalore  wickets            5.0          N    NaN
# 335986        Kolkata Knight Riders  wickets            5.0          N    NaN
#
#           umpire1         umpire2  season
# id
# 335982  Asad Rauf     RE Koertzen    2008
# 335983  MR Benson      SL Shastri    2008
# 335984  Aleem Dar  GA Pratapkumar    2008
# 335985   SJ Davis       DJ Harper    2008
# 335986  BF Bowden     K Hariharan    2008

# %%
plt.figure(figsize=(6, 11))
sns.countplot(y="city", data=matches, palette="Greens_r")
plt.title("Most matches played in city", fontsize=12)
plt.xlabel("City")
plt.ylabel("Matches")
# Out:
# Text(0, 0.5, 'Matches')

# %%
# as you can see that most matches played in Mumbai

# %%
matches.head()
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs          140.0          N    NaN
# 335983          Chennai Super Kings     runs           33.0          N    NaN
# 335984             Delhi Daredevils  wickets            9.0          N    NaN
# 335985  Royal Challengers Bangalore  wickets            5.0          N    NaN
# 335986        Kolkata Knight Riders  wickets            5.0          N    NaN
#
#           umpire1         umpire2  season
# id
# 335982  Asad Rauf     RE Koertzen    2008
# 335983  MR Benson      SL Shastri    2008
# 335984  Aleem Dar  GA Pratapkumar    2008
# 335985   SJ Davis       DJ Harper    2008
# 335986  BF Bowden     K Hariharan    2008

# %%
man_of_match_players = matches['player_of_match'].value_counts()
man_of_match_players[:10].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# as you can see that AB is most time man of match

# %%
df.head()
# Out:
#         inning  over  ball      batsman  non_striker     bowler  batsman_runs  \
# id
# 335982       1     6     5   RT Ponting  BB McCullum  AA Noffke             1
# 335982       1     6     6  BB McCullum   RT Ponting  AA Noffke             1
# 335982       1     7     1  BB McCullum   RT Ponting     Z Khan             0
# 335982       1     7     2  BB McCullum   RT Ponting     Z Khan             1
# 335982       1     7     3   RT Ponting  BB McCullum     Z Khan             1
#
#         extra_runs  total_runs  non_boundary  is_wicket dismissal_kind  \
# id
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           0             0          0            NaN
# 335982           0           1             0          0            NaN
# 335982           0           1             0          0            NaN
#
#        player_dismissed fielder extras_type           batting_team  \
# id
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
# 335982              NaN     NaN         NaN  Kolkata Knight Riders
#
#                        bowling_team
# id
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore
# 335982  Royal Challengers Bangalore

# %%
most_ball_bowled_by_bowler = df['bowler'].value_counts()
most_ball_bowled_by_bowler[:20].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# as you can see that most balls bowled by Harbhajan SIngh
